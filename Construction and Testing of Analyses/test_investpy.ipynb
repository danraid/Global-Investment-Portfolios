# %% [markdown]
# """
# # 📌 Testes com Investpy
# Este notebook tem como objetivo validar a consulta de dados financeiros utilizando a biblioteca `investpy`.
#
# ### 🔹 O que será testado?
# 1. Leitura dos dados do arquivo CSV da Interactive Brokers.
# 2. Consulta de informações sobre os ativos no `investpy`.
# 3. Validação da disponibilidade dos dados coletados.
# """

# %%
# Importar as bibliotecas necessárias
import pandas as pd
import investpy

# %%
# Solicitar o caminho do arquivo CSV da Interactive Brokers
file_path = "data/teste1.csv" 

# Carregar o arquivo CSV
df_ibkr = pd.read_csv(file_path, delimiter=';')

# %%
# Exibir as primeiras linhas do arquivo para validação
print("📊 Visualizando os primeiros dados da Interactive Brokers:")
display(df_ibkr.head())
# Out:
# 📊 Visualizando os primeiros dados da Interactive Brokers:
#   symbol                   description ibkr symbol currency product region  \
# 0      A      AGILENT TECHNOLOGIES INC           A      USD  Stocks     US
# 1     AA                    ALCOA CORP          AA      USD  Stocks     US
# 2   AABB            ASIA BROADBAND INC        AABB      USD  Stocks     US
# 3  AABVF   ABERDEEN INTERNATIONAL INC.       AABVF      USD  Stocks     US
# 4  AACAY  AAC TECHNOLOGIES H-UNSPON AD       AACAY      USD  Stocks     US
#
#   exchange *primary exchange
# 0                      NYSE*
# 1                       AMEX
# 2                  OTCLNKECN
# 3                  OTCLNKECN
# 4                   ARCAEDGE

# %%
# Criar lista para armazenar os dados coletados
dados_ativos = []

# %%
# Criar um dicionário de mapeamento de regiões da IBKR para os nomes esperados pelo Investpy
mapeamento_paises = {
    "us": "United States",
    "ca": "Canada",
    "gb": "United Kingdom",
    "de": "Germany",
    "fr": "France",
    "es": "Spain",
    "it": "Italy",
    "jp": "Japan",
    "cn": "China",
    "hk": "Hong Kong",
    "au": "Australia",
    "br": "Brazil"
}

# %%
# 📌 Passo 2: Buscar informações para cada ativo usando Investpy
for index, row in df_ibkr.iterrows():
    symbol = row["symbol"].strip()  # Pegar o símbolo
    region = row["region"].strip().lower()  # Normalizar a região para minúsculas

    # Mapear a região para o nome correto do país no Investpy
    country = mapeamento_paises.get(region, None)

    if country is None:
        print(f"⚠️ Região '{region}' não mapeada para um país do Investpy. Pulando {symbol}.")
        continue

    try:
        # 📌 Buscar dados no Investpy
        stock_data = investpy.get_stock_information(stock=symbol, country=country)

        # 📌 Extrair os dados relevantes
        dados_ativos.append({
            "Symbol": symbol,
            "Nome": stock_data.get("name", "N/A"),
            "País": country,
            "Preço Atual": stock_data.get("prev_close", "N/A"),
            "P/E Ratio": stock_data.get("p/e_ratio", "N/A"),
            "Dividend Yield": stock_data.get("dividend_yield", "N/A"),
            "Beta": stock_data.get("beta", "N/A"),
            "Volume": stock_data.get("volume", "N/A")
        })
    except Exception as e:
        print(f"❌ Erro ao buscar {symbol} ({country}): {e}")
# Out:
# ❌ Erro ao buscar A (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AA (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AABB (United States): ERR#0018: stock aabb not found, check if it is correct.
# ❌ Erro ao buscar AABVF (United States): ERR#0018: stock aabvf not found, check if it is correct.
# ❌ Erro ao buscar AACAY (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AACG (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AACOU (United States): ERR#0018: stock aacou not found, check if it is correct.
# ❌ Erro ao buscar AACS (United States): ERR#0018: stock aacs not found, check if it is correct.
# ❌ Erro ao buscar AACT (United States): ERR#0018: stock aact not found, check if it is correct.
# ❌ Erro ao buscar AACT U (United States): ERR#0018: stock aact u not found, check if it is correct.
# ❌ Erro ao buscar AACTF (United States): ERR#0018: stock aactf not found, check if it is correct.
# ❌ Erro ao buscar AADI (United States): ERR#0018: stock aadi not found, check if it is correct.
# ❌ Erro ao buscar AAGC (United States): ERR#0018: stock aagc not found, check if it is correct.
# ❌ Erro ao buscar AAGFF (United States): ERR#0018: stock aagff not found, check if it is correct.
# ❌ Erro ao buscar AAGH (United States): ERR#0018: stock aagh not found, check if it is correct.
# ❌ Erro ao buscar AAGIY (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AAGR (United States): ERR#0018: stock aagr not found, check if it is correct.
# ❌ Erro ao buscar AAGRY (United States): ERR#0018: stock aagry not found, check if it is correct.
# ❌ Erro ao buscar AAIIQ (United States): ERR#0018: stock aaiiq not found, check if it is correct.
# ❌ Erro ao buscar AAIRF (United States): ERR#0018: stock aairf not found, check if it is correct.
# ❌ Erro ao buscar AAKAY (United States): ERR#0018: stock aakay not found, check if it is correct.
# ❌ Erro ao buscar AAL (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AAM (United States): ERR#0018: stock aam not found, check if it is correct.
# ❌ Erro ao buscar AAM U (United States): ERR#0018: stock aam u not found, check if it is correct.
# ❌ Erro ao buscar AAMCF (United States): ERR#0018: stock aamcf not found, check if it is correct.
# ❌ Erro ao buscar AAME (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AAMI (United States): ERR#0018: stock aami not found, check if it is correct.
# ❌ Erro ao buscar AAMMF (United States): ERR#0018: stock aammf not found, check if it is correct.
# ❌ Erro ao buscar AAMTF (United States): ERR#0018: stock aamtf not found, check if it is correct.
# ❌ Erro ao buscar AAOI (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AAON (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AAP (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AAPI (United States): ERR#0018: stock aapi not found, check if it is correct.
# ❌ Erro ao buscar AAPJ (United States): ERR#0018: stock aapj not found, check if it is correct.
# ❌ Erro ao buscar AAPL (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AAPT (United States): ERR#0018: stock aapt not found, check if it is correct.
# ❌ Erro ao buscar AAQL (United States): ERR#0018: stock aaql not found, check if it is correct.
# ❌ Erro ao buscar AARTY (United States): ERR#0018: stock aarty not found, check if it is correct.
# ❌ Erro ao buscar AASP (United States): ERR#0018: stock aasp not found, check if it is correct.
# ❌ Erro ao buscar AAT (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar AATC (United States): ERR#0018: stock aatc not found, check if it is correct.
# ❌ Erro ao buscar AATRL (United States): ERR#0018: stock aatrl not found, check if it is correct.
# ❌ Erro ao buscar AATV (United States): ERR#0018: stock aatv not found, check if it is correct.
# ❌ Erro ao buscar AAUAF (United States): ERR#0018: stock aauaf not found, check if it is correct.
# ❌ Erro ao buscar AAUGF (United States): ERR#0018: stock aaugf not found, check if it is correct.
# ❌ Erro ao buscar AAUKF (United States): ERR#0018: stock aaukf not found, check if it is correct.
# ❌ Erro ao buscar AAVMY (United States): ERR#0018: stock aavmy not found, check if it is correct.
# ❌ Erro ao buscar AAVVF (United States): ERR#0018: stock aavvf not found, check if it is correct.
# ❌ Erro ao buscar AAWH (United States): ERR#0018: stock aawh not found, check if it is correct.
United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar ABTI (United States): ERR#0018: stock abti not found, check if it is correct.
# ❌ Erro ao buscar ABTS (United States): ERR#0018: stock abts not found, check if it is correct.
# ❌ Erro ao buscar ABTZY (United States): ERR#0018: stock abtzy not found, check if it is correct.
# ❌ Erro ao buscar ABUS (United States): ERR#0015: error 403, try again later.
# ❌ Erro ao buscar ABVC (United States): ERR#0018: stock abvc not found, check if it is correct.
# ❌ Erro ao buscar ABVE (United States): ERR#0018: stock abve not found, check if it is correct.
# ❌ Erro ao buscar ABVG (United States): ERR#0018: stock abvg not found, check if it is correct.
# ❌ Erro ao buscar ABVN (United States): ERR#0018: stock abvn not found, check if it is correct.
# ❌ Erro ao buscar ABVX (United States): ERR#0018: stock abvx not found, check if it is correct.
# ❌ Erro ao buscar ABWN (United States): ERR#0018: stock abwn not found, check if it is correct.
# ❌ Erro ao buscar AAPY (United States): ERR#0018: stock aapy not found, check if it is correct.
# ❌ Erro ao buscar AAXJ (United States): ERR#0018: stock aaxj not found, check if it is correct.
# ❌ Erro ao buscar AAXJ (United States): ERR#0018: stock aaxj not found, check if it is correct.
# ❌ Erro ao buscar ABCS (United States): ERR#0018: stock abcs not found, check if it is correct.
# ❌ Erro ao buscar ABEQ (United States): ERR#0018: stock abeq not found, check if it is correct.
# ❌ Erro ao buscar ABFL (United States): ERR#0018: stock abfl not found, check if it is correct.
# ❌ Erro ao buscar ABHY (United States): ERR#0018: stock abhy not found, check if it is correct.
# ❌ Erro ao buscar ABLD (United States): ERR#0018: stock abld not found, check if it is correct.
# ❌ Erro ao buscar ABLG (United States): ERR#0018: stock ablg not found, check if it is correct.
# ❌ Erro ao buscar ABNY (United States): ERR#0018: stock abny not found, check if it is correct.
# ❌ Erro ao buscar ABOT (United States): ERR#0018: stock abot not found, check if it is correct.
# ❌ Erro ao buscar ACES (United States): ERR#0018: stock aces not found, check if it is correct.
# ❌ Erro ao buscar ACGR (United States): ERR#0018: stock acgr not found, check if it is correct.
# ❌ Erro ao buscar ACIO (United States): ERR#0018: stock acio not found, check if it is correct.
# ❌ Erro ao buscar ACLC (United States): ERR#0018: stock aclc not found, check if it is correct.
# ❌ Erro ao buscar ACLO (United States): ERR#0018: stock aclo not found, check if it is correct.
# ❌ Erro ao buscar ACSI (United States): ERR#0018: stock acsi not found, check if it is correct.
# ❌ Erro ao buscar ACTV (United States): ERR#0018: stock actv not found, check if it is correct.
# ❌ Erro ao buscar ACVF (United States): ERR#0018: stock acvf not found, check if it is correct.
# ❌ Erro ao buscar ACWI (United States): ERR#0018: stock acwi not found, check if it is correct.
# ❌ Erro ao buscar ACWV (United States): ERR#0018: stock acwv not found, check if it is correct.
# ❌ Erro ao buscar ACWV (United States): ERR#0018: stock acwv not found, check if it is correct.
# ❌ Erro ao buscar ACWX (United States): ERR#0018: stock acwx not found, check if it is correct.
# ❌ Erro ao buscar ADFI (United States): ERR#0018: stock adfi not found, check if it is correct.
# ❌ Erro ao buscar ADIV (United States): ERR#0018: stock adiv not found, check if it is correct.
# ❌ Erro ao buscar ADME (United States): ERR#0018: stock adme not found, check if it is correct.
# ❌ Erro ao buscar AIEQ (United States): ERR#0018: stock aieq not found, check if it is correct.
# ❌ Erro ao buscar AIFD (United States): ERR#0018: stock aifd not found, check if it is correct.
# ❌ Erro ao buscar AINP (United States): ERR#0018: stock ainp not found, check if it is correct.
# ❌ Erro ao buscar AIPI (United States): ERR#0018: stock aipi not found, check if it is correct.
# ❌ Erro ao buscar AIQ (United States): ERR#0018: stock aiq not found, check if it is correct.
# ❌ Erro ao buscar AIQ (United States): ERR#0018: stock aiq not found, check if it is correct.
# ❌ Erro ao buscar AIRL (United States): ERR#0018: stock airl not found, check if it is correct.
# ❌ Erro ao buscar AIRR (United States): ERR#0018: stock airr not found, check if it is correct.
# ❌ Erro ao buscar AIRR (United States): ERR#0018: stock airr not found, check if it is correct.
# ❌ Erro ao buscar AIS (United States): ERR#0018: stock ais not found, check if it is correct.
# ❌ Erro ao buscar AIVC (United States): ERR#0018: stock aivc not found, check if it is correct.
# ❌ Erro ao buscar AIVI (United States): ERR#0018: stock aivi not found, check if it is correct.
# ❌ Erro ao buscar AIVL (United States): ERR#0018: stock aivl not found, check if it is correct.
# ❌ Erro ao buscar AIYY (United States): ERR#0018: stock aiyy not found, check if it is correct.
# ❌ Erro ao buscar AJAN (United States): ERR#0018: stock ajan not found, check if it is correct.
# ❌ Erro ao buscar AJUL (United States): ERR#0018: stock ajul not found, check if it is correct.
# ❌ Erro ao buscar ALAI (United States): ERR#0018: stock alai not found, check if it is correct.
# ❌ Erro ao buscar ALTL (United States): ERR#0018: stock altl not found, check if it is correct.
# ❌ Erro ao buscar ALTY (United States): ERR#0018: stock alty not found, check if it is correct.
# ❌ Erro ao buscar ALTY (United States): ERR#0018: stock alty not found, check if it is correct.
# ❌ Erro ao buscar AMAX (United States): ERR#0018: stock amax not found, check if it is correct.
# ❌ Erro ao buscar AMDL (United States): ERR#0018: stock amdl not found, check if it is correct.
# ❌ Erro ao buscar AMDS (United States): ERR#0018: stock amds not found, check if it is correct.

# %%
# Salvar os resultados em arquivos CSV para análise
pd.DataFrame(ativos_encontrados, columns=["Symbol"]).to_csv("ativos_encontrados.csv", index=False)
pd.DataFrame(ativos_nao_encontrados, columns=["Symbol"]).to_csv("ativos_nao_encontrados.csv", index=False)

print("📂 Resultados salvos em 'ativos_encontrados.csv' e 'ativos_nao_encontrados.csv'")
# Out:
# 📂 Resultados salvos em 'ativos_encontrados.csv' e 'ativos_nao_encontrados.csv'

# %%
# Buscar todos os ativos (stocks) disponíveis nos Estados Unidos
try:
    us_stocks = investpy.get_stocks_list(country='united states')
    print(f"✅ Encontrados {len(us_stocks)} ativos de stocks nos Estados Unidos.")
    
    # Salvar a lista em um arquivo CSV para análise posterior
    stocks_file_path = "us_stocks_list.csv"
    pd.DataFrame(us_stocks, columns=["Symbol"]).to_csv(stocks_file_path, index=False)
    
    print(f"📂 Lista salva em '{stocks_file_path}'")
except Exception as e:
    print(f"❌ Erro ao buscar os ativos: {e}")
# Out:
# ✅ Encontrados 4582 ativos de stocks nos Estados Unidos.
# 📂 Lista salva em 'us_stocks_list.csv'
